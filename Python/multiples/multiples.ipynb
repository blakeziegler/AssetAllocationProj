# %%
import numpy as np
import matplotlib as plt
import pandas as pd
import matplotlib.pyplot as plt

# %%
# See 'Read Me' github file for data details

# 2004-2024 Yahoo Finance Data (cleaned in sql)
pe = pd.read_csv("pe_ratio_clean.csv")
pe_quarterly = pd.read_csv("pe_ratio_clean_total.csv")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data
pe_quarterly = pd.read_csv("pe_ratio_clean_total.csv")

# Convert 'Date' columns to datetime if not already done
pe_quarterly['Date'] = pd.to_datetime(pe_quarterly['Date'])

# Plot the quarterly P/E ratios
plt.figure(figsize=(14, 7))

# Plot with improved aesthetics
plt.plot(pe_quarterly['Date'], pe_quarterly['value'], label='Quarterly P/E Ratio', color='teal', linewidth=2)

# Set x-axis ticks to every 10 years
plt.xticks(pd.date_range(start=pe_quarterly['Date'].min(), end=pe_quarterly['Date'].max(), freq='10Y'), rotation=45)

# Remove x-axis gridlines and enhance y-axis gridlines
plt.grid(axis='x', which='both', linestyle='', linewidth=0)
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Add labels and title
plt.title('Quarterly P/E Ratios Over Time', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=14)
plt.ylabel('P/E Ratio', fontsize=14)

# Add a legend with improved styling
plt.legend(loc='upper left', fontsize=12, frameon=True, framealpha=0.9, shadow=True, borderpad=1)

# Add a background color
plt.gca().set_facecolor('#f7f7f7')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ziegl\AppData\Local\Temp\ipykernel_28772\2976016083.py:18: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   plt.xticks(pd.date_range(start=pe_quarterly['Date'].min(), end=pe_quarterly['Date'].max(), freq='10Y'), rotation=45)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data
pe_quarterly = pd.read_csv("pe_ratio_clean_total.csv")

# Convert 'Date' columns to datetime if not already done
pe_quarterly['Date'] = pd.to_datetime(pe_quarterly['Date'])

# Normalize the 'value' column using a logarithmic transformation
pe_quarterly['log_value'] = np.log(pe_quarterly['value'])

# Plot the normalized quarterly P/E ratios
plt.figure(figsize=(14, 7))

# Plot with improved aesthetics
plt.plot(pe_quarterly['Date'], pe_quarterly['log_value'], label='Quarterly P/E Ratio (Log Normalized)', color='teal', linewidth=2)

# Set x-axis ticks to every 10 years on January 1st
start_year = pe_quarterly['Date'].dt.year.min()
end_year = pe_quarterly['Date'].dt.year.max()
x_ticks = pd.date_range(start=f'{start_year}-01-01', end=f'{end_year}-01-01', freq='10Y')

plt.xticks(x_ticks, rotation=45)

# Remove x-axis gridlines and enhance y-axis gridlines
plt.grid(axis='x', which='both', linestyle='', linewidth=0)
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Add labels and title
plt.title('Quarterly P/E Ratios Over Time (Log Normalized)', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Log Normalized P/E Ratio', fontsize=14)

# Add a legend with improved styling
plt.legend(loc='upper left', fontsize=12, frameon=True, framealpha=0.9, shadow=True, borderpad=1)

# Add a background color
plt.gca().set_facecolor('#f7f7f7')

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ziegl\AppData\Local\Temp\ipykernel_28772\3004158953.py:23: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   x_ticks = pd.date_range(start=f'{start_year}-01-01', end=f'{end_year}-01-01', freq='10Y')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the data
pe_quarterly = pd.read_csv("pe_ratio_clean_total.csv")

# Convert 'Date' columns to datetime if not already done
pe_quarterly['Date'] = pd.to_datetime(pe_quarterly['Date'])

# Normalize the 'value' column using a logarithmic transformation
pe_quarterly['log_value'] = np.log(pe_quarterly['value'])

# Define the recession periods
recession_periods = [
    ('1945-10-01', '1948-10-01'),
    ('1969-12-01', '1972-12-01'),
    ('1997-02-01', '2000-02-01'),
    ('2005-11-01', '2008-11-01'),
    ('2017-01-01', '2020-01-01')
]

# Plot the normalized quarterly P/E ratios
plt.figure(figsize=(14, 7))

# Add background shading for recession periods
for start_date, end_date in recession_periods:
    plt.axvspan(pd.to_datetime(start_date), pd.to_datetime(end_date), color='red', alpha=0.3)

# Plot the data
plt.plot(pe_quarterly['Date'], pe_quarterly['log_value'], label='Quarterly P/E Ratio (Log Normalized)', color='teal', linewidth=2)

# Set x-axis ticks to every 10 years on January 1st
start_year = pe_quarterly['Date'].dt.year.min()
end_year = pe_quarterly['Date'].dt.year.max()
x_ticks = pd.date_range(start=f'{start_year}-01-01', end=f'{end_year}-01-01', freq='5Y')

plt.xticks(x_ticks, rotation=45)

# Remove x-axis gridlines and enhance y-axis gridlines
plt.grid(axis='x', which='both', linestyle='', linewidth=0)
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Add labels and title
plt.title('Pre-Recession P/E Ratios', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Log Normalized P/E Ratio', fontsize=14)

# Add a legend with improved styling
plt.legend(loc='upper left', fontsize=12, frameon=True, framealpha=0.9, shadow=True, borderpad=1)

# Add a background color
plt.gca().set_facecolor('#f7f7f7')

# Show the plot
plt.tight_layout()
plt.show()

# Analyze data over these time periods
# Analyze current and historic large cap PE to find a similar 3.0 and 3.5 celling
# Out:
# C:\Users\ziegl\AppData\Local\Temp\ipykernel_28772\2180934935.py:36: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   x_ticks = pd.date_range(start=f'{start_year}-01-01', end=f'{end_year}-01-01', freq='5Y')

# %%
import pandas as pd

# Load the data
pe_quarterly = pd.read_csv("pe_ratio_clean_total.csv")

# Convert 'Date' column to datetime if not already done
pe_quarterly['Date'] = pd.to_datetime(pe_quarterly['Date'], format='%Y-%m-%d')

# Filter the data for the specified range (1948-2024)
start_year = 1948
end_year = 2024
filtered_data = pe_quarterly[(pe_quarterly['Date'].dt.year >= start_year) & (pe_quarterly['Date'].dt.year <= end_year)]

# Define a function to categorize into 5-year intervals
def categorize_year(date):
    year = date.year
    return f"{year // 5 * 5}-{year // 5 * 5 + 4}"

# Apply the function to create a new column for 5-year intervals
filtered_data['5_year_interval'] = filtered_data['Date'].apply(categorize_year)

# Calculate the average for each 5-year interval
averages_5_years = filtered_data.groupby('5_year_interval')['value'].mean()

# Print the results
print("Average P/E Ratios (5-year intervals from 1948-2024):")
for interval, avg in averages_5_years.items():
    print(f"{interval}: {avg:.2f}")
    
# Filter the data for the year 2024
data_2024 = pe_quarterly[pe_quarterly['Date'].dt.year == 2024]

# Calculate the average P/E ratio for 2024
average_pe_2024 = data_2024['value'].mean()

# Print the result
print(f"Average P/E Ratio for 2024: {average_pe_2024:.2f}")
# Out:
# Average P/E Ratios (5-year intervals from 1948-2024):
# 1945-1949: 7.19
# 1950-1954: 9.37
# 1955-1959: 14.28
# 1960-1964: 18.42
# 1965-1969: 17.11
# 1970-1974: 15.08
# 1975-1979: 9.28
# 1980-1984: 9.44
# 1985-1989: 14.36
# 1990-1994: 19.90
# 1995-1999: 22.90
# 2000-2004: 29.53
# 2005-2009: 34.84
# 2010-2014: 16.71
# 2015-2019: 22.44
# 2020-2024: 25.59
# Average P/E Ratio for 2024: 25.77
# C:\Users\ziegl\AppData\Local\Temp\ipykernel_28772\1797824501.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['5_year_interval'] = filtered_data['Date'].apply(categorize_year)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
pe_quarterly = pd.read_csv("pe_ratio_clean_total.csv")

# Convert 'Date' column to datetime if not already done
pe_quarterly['Date'] = pd.to_datetime(pe_quarterly['Date'], format='%Y-%m-%d')

# Filter the data for the specified range (1948-2024)
start_year = 1948
end_year = 2024
filtered_data = pe_quarterly[(pe_quarterly['Date'].dt.year >= start_year) & (pe_quarterly['Date'].dt.year <= end_year)]

# Define a function to categorize into 5-year intervals
def categorize_year(date):
    year = date.year
    return f"{year // 5 * 5}-{year // 5 * 5 + 4}"

# Apply the function to create a new column for 5-year intervals
filtered_data['5_year_interval'] = filtered_data['Date'].apply(categorize_year)

# Calculate the average for each 5-year interval
averages_5_years = filtered_data.groupby('5_year_interval')['value'].mean().reset_index()

# Convert the '5_year_interval' to a suitable format for plotting
averages_5_years['start_year'] = averages_5_years['5_year_interval'].apply(lambda x: int(x.split('-')[0]))

# Plot the 5-year interval averages
plt.figure(figsize=(14, 7))
plt.plot(averages_5_years['start_year'], averages_5_years['value'], marker='o', linestyle='-', color='teal')

# Add labels and title
plt.title('Average P/E Ratios Over 5-Year Intervals (1948-2024)', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average P/E Ratio', fontsize=14)

# Enhance gridlines
plt.grid(True, linestyle='--', linewidth=0.7, alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\ziegl\AppData\Local\Temp\ipykernel_28772\1843778701.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['5_year_interval'] = filtered_data['Date'].apply(categorize_year)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import numpy as np

# Load the data
pe_quarterly = pd.read_csv("pe_ratio_clean_total.csv")

# Convert 'Date' column to datetime if not already done
pe_quarterly['Date'] = pd.to_datetime(pe_quarterly['Date'], format='%Y-%m-%d')

# Filter the data for the specified range (1948-2024)
start_year = 1948
end_year = 2024
filtered_data = pe_quarterly[(pe_quarterly['Date'].dt.year >= start_year) & 
                             (pe_quarterly['Date'].dt.year <= end_year)].copy()

# Define a function to categorize into 3-year intervals
def categorize_year(date):
    year = date.year
    return f"{year // 3 * 3}-{year // 3 * 3 + 2}"

# Apply the function to create a new column for 3-year intervals
filtered_data['3_year_interval'] = filtered_data['Date'].apply(categorize_year)

# Calculate the average for each 3-year interval
averages_3_years = filtered_data.groupby('3_year_interval')['value'].mean().reset_index()

# Convert the '3_year_interval' to a suitable format for plotting
averages_3_years['start_year'] = averages_3_years['3_year_interval'].apply(lambda x: int(x.split('-')[0]))

# Linear Regression
X = averages_3_years['start_year'].values.reshape(-1, 1)
y = averages_3_years['value'].values
model = LinearRegression().fit(X, y)
y_pred = model.predict(X)

# Calculate R-squared
r_squared = r2_score(y, y_pred)

# Extend the dataset with future years (10 years into the future)
future_years = list(range(2025, 2035))
future_X = np.array(future_years).reshape(-1, 1)
future_y_pred = model.predict(future_X)

# Combine current and future data for plotting
all_years = np.concatenate([X.flatten(), future_X.flatten()])
all_predictions = np.concatenate([y_pred, future_y_pred])

# Plot the 3-year interval averages
plt.figure(figsize=(14, 7))
plt.plot(averages_3_years['start_year'], averages_3_years['value'], marker='o', linestyle='-', color='teal', label='P/E Ratio')

# Add labels and title
plt.title('Average P/E Ratios Over 3-Year Intervals (1948-2034)', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average P/E Ratio', fontsize=14)

# Enhance gridlines
plt.grid(True, linestyle='--', linewidth=0.7, alpha=0.7)

# Plot the combined regression line
plt.plot(all_years, all_predictions, color='red', linestyle='--', label=f'Linear Regression (R² = {r_squared:.2f})')

# Set x-axis ticks every 6 years
plt.xticks(np.arange(start_year, 2035, 6))

# Add legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# Print the regression coefficients
print("Linear Regression Coefficients:")
print(f"Slope: {model.coef_[0]:.2f}")
print(f"R²: {r_squared:.2f}")

# Print the forecasted P/E ratios
forecasted_pe_ratios = pd.DataFrame({'Year': future_years, 'Forecasted P/E Ratio': future_y_pred})
print("\nForecasted P/E Ratios (2025-2034):")
print(forecasted_pe_ratios)
# Out:
# Linear Regression Coefficients:
# Slope: 0.23
# R²: 0.37
#
# Forecasted P/E Ratios (2025-2034):
#    Year  Forecasted P/E Ratio
# 0  2025             27.381496
# 1  2026             27.609100
# 2  2027             27.836704
# 3  2028             28.064309
# 4  2029             28.291913
# 5  2030             28.519517
# 6  2031             28.747121
# 7  2032             28.974725
# 8  2033             29.202329
# 9  2034             29.429933

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import numpy as np

# Load the data
pe_quarterly = pd.read_csv("pe_ratio_clean_total.csv")

# Convert 'Date' column to datetime if not already done
pe_quarterly['Date'] = pd.to_datetime(pe_quarterly['Date'], format='%Y-%m-%d')

# Filter the data for the specified range (2010-2024)
start_year = 2010
end_year = 2024
filtered_data = pe_quarterly[(pe_quarterly['Date'].dt.year >= start_year) & 
                             (pe_quarterly['Date'].dt.year <= end_year)].copy()

# Define a function to categorize into quarters
def categorize_quarter(date):
    year = date.year
    quarter = (date.month - 1) // 3 + 1
    return f"{year}-Q{quarter}"

# Apply the function to create a new column for quarters
filtered_data['quarter'] = filtered_data['Date'].apply(categorize_quarter)

# Calculate the average for each quarter
averages_quarter = filtered_data.groupby('quarter')['value'].mean().reset_index()

# Convert the 'quarter' to a suitable format for plotting
averages_quarter['year_quarter'] = averages_quarter['quarter'].apply(lambda x: int(x.split('-')[0]) + (int(x.split('-')[1][1]) - 1) / 4)

# Linear Regression
X = averages_quarter['year_quarter'].values.reshape(-1, 1)
y = averages_quarter['value'].values
model = LinearRegression().fit(X, y)
y_pred = model.predict(X)

# Calculate R-squared
r_squared = r2_score(y, y_pred)

# Extend the dataset with future quarters (10 years into the future, 40 quarters)
future_quarters = list(range(2025, 2028))
future_quarters = [f"{year}-Q{quarter}" for year in future_quarters for quarter in range(1, 5)]
future_year_quarters = np.array([int(fq.split('-')[0]) + (int(fq.split('-')[1][1]) - 1) / 4 for fq in future_quarters]).reshape(-1, 1)
future_y_pred = model.predict(future_year_quarters)

# Combine current and future data for plotting
all_year_quarters = np.concatenate([X.flatten(), future_year_quarters.flatten()])
all_predictions = np.concatenate([y_pred, future_y_pred])

# Plot the quarterly averages
plt.figure(figsize=(14, 7))
plt.plot(averages_quarter['year_quarter'], averages_quarter['value'], marker='o', linestyle='-', color='teal', label='P/E Ratio')

# Add labels and title
plt.title('Average P/E Ratios by Quarter (2010-2024)', fontsize=16, fontweight='bold')
plt.xlabel('Year', fontsize=14)
plt.ylabel('Average P/E Ratio', fontsize=14)

# Enhance gridlines
plt.grid(True, linestyle='--', linewidth=0.7, alpha=0.7)

# Plot the combined regression line
plt.plot(all_year_quarters, all_predictions, color='red', linestyle='--', label=f'Linear Regression (R² = {r_squared:.2f})')

# Set x-axis ticks every 2 years
plt.xticks(np.arange(start_year, 2028, 2))

# Add legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# Print the regression coefficients
print("Linear Regression Coefficients:")
print(f"Slope: {model.coef_[0]:.2f}")
print(f"R²: {r_squared:.2f}")

# Print the forecasted P/E ratios
forecasted_pe_ratios = pd.DataFrame({'Year_Quarter': future_quarters, 'Forecasted P/E Ratio': future_y_pred})
print("\nForecasted P/E Ratios (2025-2028):")
print(forecasted_pe_ratios)
# Out:
# Linear Regression Coefficients:
# Slope: 0.78
# R²: 0.57
#
# Forecasted P/E Ratios (2025-2028):
#    Year_Quarter  Forecasted P/E Ratio
# 0       2025-Q1             27.560745
# 1       2025-Q2             27.754983
# 2       2025-Q3             27.949221
# 3       2025-Q4             28.143460
# 4       2026-Q1             28.337698
# 5       2026-Q2             28.531936
# 6       2026-Q3             28.726174
# 7       2026-Q4             28.920413
# 8       2027-Q1             29.114651
# 9       2027-Q2             29.308889
# 10      2027-Q3             29.503127
# 11      2027-Q4             29.697365

# %%
import pandas as pd
from tabulate import tabulate

# Data
funds = ['VV', 'QQQ', 'VB', 'RSP']
pe_ratios = [27.61, 39.07, 14.39, 20.90]
total_top10 = [33.82, 48.64, 3.83, 2.73]
top5_vv = {'MSFT': 6.91, 'AAPL': 6.32, 'NVDA': 5.84, 'AMZN': 3.70, 'META': 2.30}
top5_qqq = {'MSFT': 8.51, 'AAPL': 8.19, 'NVDA': 7.56, 'AMZN': 5.05, 'META': 4.51}
top5_vb = {'DECK': 0.50, 'TRGP': 0.47, 'MSTR': 0.41, 'AXON': 0.41, 'PTC': 0.36}
top5_rsp = {'FSLR': 0.34, 'NEE': 0.28, 'MRNA': 0.28, 'VST': 0.27, 'NRG': 0.27}

# Create a DataFrame
data = {
    'Fund': ['VV', 'QQQ', 'VB', 'RSP'],
    'P/E Ratio': pe_ratios,
    '% Assets in Top 10 Holdings': total_top10,
    'Top 5 Holdings': [
        ', '.join([f'{k} ({v}%)' for k, v in top5_vv.items()]),
        ', '.join([f'{k} ({v}%)' for k, v in top5_qqq.items()]),
        ', '.join([f'{k} ({v}%)' for k, v in top5_vb.items()]),
        ', '.join([f'{k} ({v}%)' for k, v in top5_rsp.items()])
    ]
}

df = pd.DataFrame(data)

# Display the table
print(tabulate(df, headers='keys', tablefmt='grid', showindex=False))
# Out:
# +--------+-------------+-------------------------------+----------------------------------------------------------------------+
# | Fund   |   P/E Ratio |   % Assets in Top 10 Holdings | Top 5 Holdings                                                       |
# +========+=============+===============================+======================================================================+
# | VV     |       27.61 |                         33.82 | MSFT (6.91%), AAPL (6.32%), NVDA (5.84%), AMZN (3.7%), META (2.3%)   |
# +--------+-------------+-------------------------------+----------------------------------------------------------------------+
# | QQQ    |       39.07 |                         48.64 | MSFT (8.51%), AAPL (8.19%), NVDA (7.56%), AMZN (5.05%), META (4.51%) |
# +--------+-------------+-------------------------------+----------------------------------------------------------------------+
# ...

# %%
import matplotlib.pyplot as plt

# Data
funds = ['VV', 'QQQ', 'VB', 'RSP']
pe_ratios = [27.61, 39.07, 14.39, 20.90]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # Custom color palette
sp500_pe = 26.26  # Current P/E ratio for the S&P 500

# Plot
plt.figure(figsize=(12, 8))
bars = plt.bar(funds, pe_ratios, color=colors)

# Add data labels
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, round(yval, 2), ha='center', fontsize=12, fontweight='bold')

# Customize fonts and styles
plt.xlabel('Funds', fontsize=14, fontweight='bold')
plt.ylabel('P/E Ratio', fontsize=14, fontweight='bold')
plt.title('P/E Ratios of Different Funds', fontsize=16, fontweight='bold')

# Add gridlines
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Add the red dotted line for S&P 500 P/E ratio
plt.axhline(y=sp500_pe, color='red', linestyle='--', linewidth=2, label=f'S&P 500 P/E Ratio ({sp500_pe})')

# Customize ticks
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
funds = ['Large Cap', 'Aggressive Large Cap', 'Small Cap', 'Equal Weight']
pe_ratios_2015 = [20.5, 23.1, 16.1, 19.7]
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # Custom color palette
historic_ratio_2015 = 22.31  # Historical S&P 500 P/E ratio for 2015

# Plot
plt.figure(figsize=(12, 8))
bars = plt.bar(funds, pe_ratios_2015, color=colors)

# Add data labels
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, round(yval, 1), ha='center', fontsize=12, fontweight='bold')

# Customize fonts and styles
plt.xlabel('Funds', fontsize=14, fontweight='bold')
plt.ylabel('P/E Ratio', fontsize=14, fontweight='bold')
plt.title('Average P/E Ratios of Different Funds in 2015', fontsize=16, fontweight='bold')

# Add gridlines
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Add the red dotted line for historical S&P 500 P/E ratio in 2015
plt.axhline(y=historic_ratio_2015, color='red', linestyle='--', linewidth=2, label=f'S&P 500 P/E Ratio (2015) ({historic_ratio_2015})')

# Customize ticks
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

# Set y-axis limit
plt.ylim(0, 32)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
import yfinance as yf
import pandas as pd

# List of tickers for the Magnificent 7
tickers = ["AAPL", "MSFT", "GOOGL", "AMZN", "META", "NVDA", "TSLA"]

# Fetch the P/E ratios
pe_ratios = {}

for ticker in tickers:
    stock = yf.Ticker(ticker)
    pe_ratio = stock.info.get('trailingPE', 'N/A')
    pe_ratios[ticker] = pe_ratio

# Print the P/E ratios
for ticker, pe_ratio in pe_ratios.items():
    print(f"{ticker}: {pe_ratio}")

# Calculate the average P/E ratio
valid_pe_ratios = [pe for pe in pe_ratios.values() if pe != 'N/A']
average_pe_ratio = sum(valid_pe_ratios) / len(valid_pe_ratios) if valid_pe_ratios else 'N/A'

print(f"\nAverage P/E Ratio: {average_pe_ratio}")

# If you want to store it in a list of tuples
pe_ratios_list = [(ticker, pe_ratio) for ticker, pe_ratio in pe_ratios.items()]

# Save to CSV
df = pd.DataFrame(pe_ratios_list, columns=['Ticker', 'P/E Ratio'])
df.to_csv('magnificent_7_pe_ratios.csv', index=False)

print("Data saved to magnificent_7_pe_ratios.csv")
# Out:
# AAPL: 32.806854
# MSFT: 38.764095
# GOOGL: 27.937117
# AMZN: 53.98045
# META: 28.97816
# NVDA: 72.670586
# TSLA: 50.73846
#
# Average P/E Ratio: 43.69653171428571
# Data saved to magnificent_7_pe_ratios.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file
df = pd.read_csv('magnificent_7_pe_ratios.csv')

# Calculate the average P/E ratio for the Magnificent 7
average_pe_magnificent_7 = df['P/E Ratio'].mean()

# Current average P/E ratio for the S&P 500
current_sp500_pe = 26.26

# Data for the bar graph
labels = ['Magnificent 7', 'S&P 500']
pe_ratios = [average_pe_magnificent_7, current_sp500_pe]
colors = ['#1f77b4', '#ff7f0e']  # Custom color palette

# Plotting
plt.figure(figsize=(12, 8))
bars = plt.bar(labels, pe_ratios, color=colors)

# Add data labels
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, round(yval, 2), ha='center', fontsize=12, fontweight='bold')

# Customize fonts and styles
plt.xlabel('Group', fontsize=14, fontweight='bold')
plt.ylabel('P/E Ratio', fontsize=14, fontweight='bold')
plt.title('Comparison of Average P/E Ratios', fontsize=16, fontweight='bold')

# Add gridlines
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Customize ticks
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

# Set y-axis limit
plt.ylim(0, max(pe_ratios) + 5)

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file
df = pd.read_csv('magnificent_7_pe_ratios.csv')

# Current average P/E ratio for the S&P 500
current_sp500_pe = 26.26

# Data for the bar graph
labels = df['Ticker'].tolist()
pe_ratios = df['P/E Ratio'].tolist()
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2']  # Custom color palette

# Plotting
plt.figure(figsize=(12, 8))
bars = plt.bar(labels, pe_ratios, color=colors)

# Add data labels
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.5, round(yval, 2), ha='center', fontsize=12, fontweight='bold')

# Customize fonts and styles
plt.xlabel('Stocks', fontsize=14, fontweight='bold')
plt.ylabel('P/E Ratio', fontsize=14, fontweight='bold')
plt.title('P/E Ratios of the Magnificent 7 Stocks', fontsize=16, fontweight='bold')

# Add gridlines
plt.grid(axis='y', linestyle='--', linewidth=0.7, alpha=0.7)

# Add the red dotted line for the S&P 500 average P/E ratio
plt.axhline(y=current_sp500_pe, color='red', linestyle='--', linewidth=2, label=f'S&P 500 P/E Ratio ({current_sp500_pe})')

# Customize ticks
plt.xticks(fontsize=12, fontweight='bold')
plt.yticks(fontsize=12, fontweight='bold')

# Set y-axis limit
plt.ylim(0, max(pe_ratios) + 10)

# Add legend
plt.legend()

# Show plot
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file
df = pd.read_csv('magnificent_7_pe_ratios.csv')

# Manually input the annual EPS growth rates for the Magnificent 7 companies
# (In percentage format, e.g., 15 for 15%)
# Based on next year estimates
growth_rates = {
    'AAPL': 10.6,
    'MSFT': 12.6,
    'GOOGL': 13.6,
    'AMZN': 27.3,
    'META': 14.4,
    'NVDA': 33.9,
    'TSLA': 32.9
}

# Add the growth rates to the DataFrame
df['Growth Rate (%)'] = df['Ticker'].map(growth_rates)

# Calculate the PEG ratio
df['PEG Ratio'] = df.apply(lambda row: row['P/E Ratio'] / row['Growth Rate (%)'] if row['Growth Rate (%)'] != 0 else None, axis=1)


# df.to_csv('magnificent_7_pe_peg_ratios.csv', index=False)
# Print the DataFrame with PEG Ratios
print(df)

# Save the DataFrame with PEG Ratios to a new CSV file
# Out:
#   Ticker  P/E Ratio  Growth Rate (%)  PEG Ratio
# 0   AAPL  32.806854             10.6   3.094986
# 1   MSFT  38.764095             12.6   3.076515
# 2  GOOGL  27.937117             13.6   2.054200
# 3   AMZN  53.980450             27.3   1.977306
# 4   META  28.978160             14.4   2.012372
# 5   NVDA  72.670586             33.9   2.143675
# 6   TSLA  50.738460             32.9   1.542202

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from the CSV file
df = pd.read_csv('magnificent_7_pe_peg_ratios.csv')

# Determine if a stock is overvalued, fairly valued, or undervalued based on the PEG ratio
def assess_valuation(peg_ratio):
    if peg_ratio < 0.4:
        return 'Very Undervalued'
    elif 0.4 <= peg_ratio < 0.8:
        return 'Undervalued'
    elif 0.8 <= peg_ratio < 1.2:
        return 'Fairly Valued'
    elif 1.2 <= peg_ratio < 1.6:
        return 'Overvalued'
    else:
        return 'Very Overvalued'

# Apply the assessment to the DataFrame
df['Valuation'] = df['PEG Ratio'].apply(assess_valuation)

# Print the updated DataFrame
print(df)

# Save the updated DataFrame to a new CSV file
# df.to_csv('magnificent_7_valuation.csv', index=False)
# Out:
#   Ticker  P/E Ratio  Growth Rate (%)  PEG Ratio        Valuation
# 0   AAPL  32.806854             10.6   3.094986  Very Overvalued
# 1   MSFT  38.764095             12.6   3.076515  Very Overvalued
# 2  GOOGL  27.937117             13.6   2.054200  Very Overvalued
# 3   AMZN  53.980450             27.3   1.977306  Very Overvalued
# 4   META  28.978160             14.4   2.012372  Very Overvalued
# 5   NVDA  72.670586             33.9   2.143675  Very Overvalued
# 6   TSLA  50.738460             32.9   1.542202       Overvalued
